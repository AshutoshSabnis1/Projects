# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)

# %%
df=pd.read_csv("car.csv")

# %%
df.head()
# Out:
#    symboling normalized_losses Fuel_type make num_of_doors   aspiration  \
# 0          3                 ?       gas  std          two  convertible
# 1          3                 ?       gas  std          two  convertible
# 2          1                 ?       gas  std          two    hatchback
# 3          2               164       gas  std         four        sedan
# 4          2               164       gas  std         four        sedan
#
#   wheel_base engine_location  drive_wheels   body_style  length  width  \
# 0        rwd           front          88.6  alfa-romero   168.8   64.1
# 1        rwd           front          88.6  alfa-romero   168.8   64.1
# 2        rwd           front          94.5  alfa-romero   171.2   65.5
# 3        fwd           front          99.8         audi   176.6   66.2
# 4        4wd           front          99.4         audi   176.6   66.4
#
#    height  curb_weight engine_type num_of_cylinders  engine_size fuel_system  \
# 0    48.8         2548        dohc             four          130        mpfi
# 1    48.8         2548        dohc             four          130        mpfi
# 2    52.4         2823        ohcv              six          152        mpfi
# 3    54.3         2337         ohc             four          109        mpfi
# 4    54.3         2824         ohc             five          136        mpfi
#
#    bore stroke  compression_ratio horsepower peak_rpm  city_mpg  highway_mpg  \
# 0  3.47   2.68                9.0        111     5000        21           27
# 1  3.47   2.68                9.0        111     5000        21           27
# 2  2.68   3.47                9.0        154     5000        19           26
# 3  3.19    3.4               10.0        102     5500        24           30
# 4  3.19    3.4                8.0        115     5500        18           22
#
#    price
# 0  13495
# 1  16500
# 2  16500
# 3  13950
# 4  17450

# %%
df.tail()
# Out:
#      symboling normalized_losses Fuel_type   make num_of_doors aspiration  \
# 200         -1                95       gas    std         four      sedan
# 201         -1                95       gas  turbo         four      sedan
# 202         -1                95       gas    std         four      sedan
# 203         -1                95    diesel  turbo         four      sedan
# 204         -1                95       gas  turbo         four      sedan
#
#     wheel_base engine_location  drive_wheels body_style  length  width  \
# 200        rwd           front         109.1      volvo   188.8   68.9
# 201        rwd           front         109.1      volvo   188.8   68.8
# 202        rwd           front         109.1      volvo   188.8   68.9
# 203        rwd           front         109.1      volvo   188.8   68.9
# 204        rwd           front         109.1      volvo   188.8   68.9
#
#      height  curb_weight engine_type num_of_cylinders  engine_size  \
# 200    55.5         2952         ohc             four          141
# 201    55.5         3049         ohc             four          141
# 202    55.5         3012        ohcv              six          173
# 203    55.5         3217         ohc              six          145
# 204    55.5         3062         ohc             four          141
#
#     fuel_system  bore stroke  compression_ratio horsepower peak_rpm  city_mpg  \
# 200        mpfi  3.78   3.15                9.5        114     5400        23
# 201        mpfi  3.78   3.15                8.7        160     5300        19
# 202        mpfi  3.58   2.87                8.8        134     5500        18
# 203         idi  3.01    3.4               23.0        106     4800        26
# 204        mpfi  3.78   3.15                9.5        114     5400        19
#
#      highway_mpg  price
# 200           28  16845
# 201           25  19045
# 202           23  21485
# 203           27  22470
# 204           25  22625

# %%
df=df.replace("?",np.nan)

# %%
df.isnull().sum()[df.isnull().sum()*100/df.shape[0]>40]
# Out:
# Series([], dtype: int64)

# %%
df.isnull().sum()
# Out:
# symboling             0
# normalized_losses    41
# Fuel_type             0
# make                  0
# num_of_doors          2
# aspiration            0
# wheel_base            0
# engine_location       0
# drive_wheels          0
# body_style            0
# length                0
# width                 0
# height                0
# curb_weight           0
# engine_type           0
# num_of_cylinders      0
# engine_size           0
# fuel_system           0
# bore                  4
# stroke                4
# compression_ratio     0
# horsepower            2
# peak_rpm              2
# city_mpg              0
# highway_mpg           0
# price                 4
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized_losses  164 non-null    object
#  2   Fuel_type          205 non-null    object
#  3   make               205 non-null    object
#  4   num_of_doors       203 non-null    object
#  5   aspiration         205 non-null    object
#  6   wheel_base         205 non-null    object
#  7   engine_location    205 non-null    object
#  8   drive_wheels       205 non-null    float64
#  9   body_style         205 non-null    object
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb_weight        205 non-null    int64
#  14  engine_type        205 non-null    object
#  15  num_of_cylinders   205 non-null    object
#  16  engine_size        205 non-null    int64
#  17  fuel_system        205 non-null    object
#  18  bore               201 non-null    object
#  19  stroke             201 non-null    object
#  20  compression_ratio  205 non-null    float64
#  21  horsepower         203 non-null    object
#  22  peak_rpm           203 non-null    object
#  23  city_mpg           205 non-null    int64
#  24  highway_mpg        205 non-null    int64
#  25  price              201 non-null    object
# dtypes: float64(5), int64(5), object(16)
# memory usage: 41.8+ KB

# %%
df.normalized_losses=df.normalized_losses.astype("float")
df.bore =df.bore.astype("float")
df.stroke =df.stroke.astype("float")
df.horsepower=df.horsepower.astype("float")
df.peak_rpm =df.peak_rpm.astype("float")
df.price=df.price.astype("float")

# %%
df.normalized_losses=df.normalized_losses.fillna(df.normalized_losses.mean())

# %%
df.bore=df.bore.fillna(df.bore.mean())

# %%
df.stroke=df.stroke.fillna(df.stroke.mean())

# %%
df.horsepower=df.horsepower.fillna(df.horsepower.mean())

# %%
df.peak_rpm=df.peak_rpm.fillna(df.peak_rpm.mean())

# %%
df.num_of_doors=df.num_of_doors.fillna("four")

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized_losses    0
# Fuel_type            0
# make                 0
# num_of_doors         0
# aspiration           0
# wheel_base           0
# engine_location      0
# drive_wheels         0
# body_style           0
# length               0
# width                0
# height               0
# curb_weight          0
# engine_type          0
# num_of_cylinders     0
# engine_size          0
# fuel_system          0
# bore                 0
# stroke               0
# compression_ratio    0
# horsepower           0
# peak_rpm             0
# city_mpg             0
# highway_mpg          0
# price                4
# dtype: int64

# %%
df.shape
# Out:
# (205, 26)

# %%
df=df.dropna() # Drop null values from Target variable

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df[df.select_dtypes(include=["object"]).columns]=df[df.select_dtypes(include=["object"]).columns].apply(le.fit_transform)

# %%
#df=df1

# %%
from sklearn.model_selection import train_test_split
a_train,a_test=train_test_split(df,test_size=0.2)

# %%
a_train_x=a_train.iloc[:,0:-1]
a_train_y=a_train.iloc[:,-1]

# %%
a_test_x=a_test.iloc[:,0:-1]
a_test_y=a_test.iloc[:,-1]

# %%
from sklearn.linear_model import LinearRegression
le=LinearRegression()
le.fit(a_train_x,a_train_y)
# Out:
# LinearRegression()

# %%
Rsquare=le.score(a_test_x,a_test_y)
Rsquare
# Out:
# 0.9188806828868719

# %%
N=a_test_x.shape[0]
K=a_test_x.shape[1]
adj=1-(1-Rsquare)*(N-1)/(N-K-1)
adj
# Out:
# 0.7836818210316583

# %%
pred_train=le.predict(a_train_x)
pred_test=le.predict(a_test_x)

# %%
err_train=a_train_y-pred_train
err_test=a_test_y-pred_test

# %%
mse=np.mean(np.square(err_test))

# %%
mse
# Out:
# 5465565.046633103

# %%
rmse=np.sqrt(mse)
rmse
# Out:
# 2337.8547958829913

# %%
mape=np.mean(np.abs(err_test*100/a_test_y))

# %%
mape
# Out:
# 16.560475031535987

# %%
import matplotlib.pyplot as plt
plt.plot(err_train,"*")

# %%
plt.hist(err_train,bins=20,edgecolor="r");

# %%
import seaborn as sns
pred_actual=pd.DataFrame()
pred_actual["Actual"]=a_train_y
pred_actual["Predicted"]=pred_train
sns.jointplot(x="Actual",y="Predicted",data=pred_actual,kind="reg")

# %%
# 121   6692.0   4511.555413
# 119   7957.0   7907.668052
# 185   8195.0   8949.725868
# 167   8449.0  13029.130416
# 58   15645.0  12707.471901
# 13   21105.0  17911.290358
# 111  15580.0  19989.827593
# 108  13200.0  18874.215918
# 101  13499.0  20829.674447
# 175   9988.0   9704.963812
# 28    8921.0  12776.081446
# 70   31600.0  27271.149763
# 19    6295.0   7655.210513
# 177  11248.0   9798.868145
# 140   7603.0   7040.116548
# 78    6669.0   6524.820664
# 55   10945.0  10782.440547
# 166   9538.0   9587.091267
# 61   10595.0  11348.209852
# 170  11199.0  13325.782740
# 93    7349.0   4962.796289
# 127  34028.0  33278.000000
# 21    5572.0   6755.323995
# 184   7995.0   8379.870563
# 33    6529.0   8581.190311
# 148   8013.0   7643.360593
# 181  15750.0  16680.083538
# 204  22625.0  18971.904661
# 85    6989.0   9049.571022
# 67   25552.0  25387.743753
# 29   12964.0  14759.781015
# 76    5389.0   5809.120302
# 103  13499.0  20896.299819
# 16   41315.0  27224.414350
# 98    8249.0   6980.395236
# 130   9295.0   9682.819322
# 32    5399.0   6656.828511
# 18    5151.0   1434.786926
# 60    8495.0  11476.470895
# 24    6229.0   7496.219109
# 143   9960.0  10240.985261
# 51    6095.0   7255.256764
# 59    8845.0  11348.209852
# 155   8778.0   6263.920199
# 62   10245.0  11476.470895
# 91    6649.0   5510.964264
# 118   5572.0   4965.046307
# 160   7738.0   5537.274107
# 126  32528.0  33278.000000
# 0    13495.0  15558.149547
# 135  15510.0  13139.036088
# 163   8058.0   5301.757026
# 99    8949.0  10845.981185
# 183   7975.0   8355.261921
# 50    5195.0   6596.686594
# 144   9233.0   7584.664585
# 134  15040.0  17746.459829

# %%
def remove_outlier(df,col,k):
    mean=df[col].mean()
    global df1
    sd=df[col].std()
    final=[x for x in df[col] if(x>mean-k*sd)]
    final=[x for x in final if(x<mean+k*sd)]
    df1=df.loc[df[col].isin(final)]; print(df1.shape)
    print("Number of outliers removed-------------> ",df.shape[0]-df1.shape[0])

# %%
remove_outlier(df,"price",2)
# Out:
# (187, 26)
# Number of outliers removed------------->  14

# %%
from sklearn.linear_model import Ridge
r=Ridge()
r.fit(a_train_x,a_train_y)
# Out:
# Ridge()

# %%
r.score(a_test_x,a_test_y)
# Out:
# 0.9139202176779508

# %%
pred_r_train=r.predict(a_train_x)
pred_r_test=r.predict(a_test_x)

# %%
err_r_train=a_train_y-pred_r_train
err_r_test=a_test_y-pred_r_test

# %%
mse1=np.mean(np.square(err_r_train))
mse2=np.mean(np.square(err_r_test))

# %%
mse1
# Out:
# 7356245.781690637

# %%
mse2
# Out:
# 5799785.6272022

# %%
# Lasso Regression
from sklearn.linear_model import Lasso
las=Lasso()
las.fit(a_train_x,a_train_y)
# Out:
# Lasso()

# %%
las.score(a_test_x,a_test_y)
# Out:
# 0.9194024780404011

# %%
pred1=las.predict(a_train_x)
pred2=las.predict(a_test_x)

# %%
msel=las.score(a_train_x,a_train_y)
mset=las.score(a_test_x,a_test_y)

# %%
msel
# Out:
# 0.8839325992280822

# %%
mset
# Out:
# 0.9194024780404011
